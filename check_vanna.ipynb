# %%
import os
from vanna.openai import OpenAI_Chat
from openai import AzureOpenAI
from vanna.chromadb import ChromaDB_VectorStore

# %%
class MyVanna(ChromaDB_VectorStore, OpenAI_Chat):
    def __init__(self, config=None):
        ChromaDB_VectorStore.__init__(self, config=config)
        OpenAI_Chat.__init__(self, client=AzureOpenAI(
                                 api_version="2024-12-01-preview",
                                 azure_endpoint="https://llmcoechangemateopenai2.openai.azure.com/",
                                 api_key=os.getenv("AZURE_OPENAI_KEY"),
                              ), config=config) # Make sure to put your AzureOpenAI client here

# %%
vn = MyVanna(config={'model': 'gpt-4o-dev', 'path': './chroma_langchain_db'})
# Out:
# Failed to send telemetry event ClientStartEvent: capture() takes 1 positional argument but 3 were given
# Failed to send telemetry event ClientCreateCollectionEvent: capture() takes 1 positional argument but 3 were given
# Failed to send telemetry event ClientCreateCollectionEvent: capture() takes 1 positional argument but 3 were given
# Failed to send telemetry event ClientCreateCollectionEvent: capture() takes 1 positional argument but 3 were given

# %%
vn.get_training_data()
# Out:
# Failed to send telemetry event CollectionGetEvent: capture() takes 1 positional argument but 3 were given
# Failed to send telemetry event CollectionGetEvent: capture() takes 1 positional argument but 3 were given
# Failed to send telemetry event CollectionGetEvent: capture() takes 1 positional argument but 3 were given
#                                             id  \
# 0     a708b31d-3e52-5139-9bb8-35e6b372c65e-sql
# 1     1de2e10c-69ce-587b-9153-45a2a1541812-sql
# 2     7ff5180c-23c5-5da9-a13a-c01c6ed55521-sql
# 3     f3c5f0ad-913d-56db-a932-21cd79c5e47e-sql
# 4     b2abdd83-db42-57e7-9874-29727fdc6f38-sql
# ..                                         ...
# 102  82154927-a22c-4aa8-9324-dff7eedbca67-TGPS
# 103  1f506980-69b2-4349-8e81-18f2b12b9a8b-TGPS
# 104  74a3df73-d7c9-481c-a06a-30151c452f97-TGPS
# 105  962e18ff-c54a-4a8a-9b2d-abf4ec6c929e-TGPS
# 106  0f6da3bf-dcfe-4151-9adc-760de568f38d-TGPS
#
#                                               question  \
# 0    What is the business question this SQL query i...
# 1    What is the product information for Accenture'...
# 2    What are the details of drivers associated wit...
# 3    What are the detailed attributes and related q...
# 4    What are the details of driver groups associat...
# ..                                                 ...
# 102                                               None
# 103                                               None
# 104                                               None
# 105                                               None
# 106                                               None
#
#                                                content training_data_type
# 0                                                   --                sql
# 1    -- Query 1: Retrieve the product information f...                sql
# 2    -- Query 2: Fetch detailed information about d...                sql
# 3    -- Query 3: Retrieve detailed information abou...                sql
# 4    -- Query 4: Fetch information about driver gro...                sql
# ..                                                 ...                ...
# 102  ## Slide 34\n- Risks & Roadblocks\n- DRIVER RE...      documentation
# 103  ## Slide 39\n- Business Leadership\n- DRIVER R...      documentation
# 104  ## Slide 44\n- Accountability\n- DRIVER RESULT...      documentation
# 105  ## Slide 53\n- cmt DATABASE - OVERALL\n- CMT I...      documentation
# 106  ## Slide 54\n- CMT | OVERALL\n- MAJORITY OF TH...      documentation
#
# [120 rows x 4 columns]

# %%
question = "How many drivers for company Accenture, product Transformation GPS in Cycle 1? Visualize in table"

sql_query, result_df, _ = vn.ask(
        question=question,
        print_results=False,
        visualize=False,
        allow_llm_to_see_data=True)
# Out:
# Failed to send telemetry event CollectionQueryEvent: capture() takes 1 positional argument but 3 were given
# Add of existing embedding ID: 44e58c87-f54d-5c7c-a0f9-4c8b22025606-sql
# Add of existing embedding ID: 44e58c87-f54d-5c7c-a0f9-4c8b22025606-sql
# Add of existing embedding ID: 44e58c87-f54d-5c7c-a0f9-4c8b22025606-sql
# Add of existing embedding ID: 6cc8d75f-ffc7-5366-af1b-2ab229490012-sql
# Failed to send telemetry event CollectionQueryEvent: capture() takes 1 positional argument but 3 were given
# Failed to send telemetry event CollectionQueryEvent: capture() takes 1 positional argument but 3 were given
# SQL Prompt: [{'role': 'system', 'content': "You are a SQL expert. Please help to generate a SQL query to answer the question. Your response should ONLY be based on the given context and follow the response guidelines and format instructions. \n===Additional Context \n\n## Slide 6\n\n- 6\n- TGPS 2.0 | TGPS Model\n- Overview\n- The Transformation GPS 2.0 model provides a powerful framework for successful change.\n- There are two Outcome drivers, two Turbulence drivers and 10 Transformation drivers in Transformation GPS. Each driver contains up to five questions in the TGPS standard questionnaire.\n- OUTCOMES\n- The entire purpose of the change, delivering the benefits of the change while improving the performance of the organization.\n- TURBULENCE\n- This is the environment that the transformation is taking place within. This includes the impact of other ongoing changes, the nature of the change itself and the risks and roadblocks to success.\n- TRANSFORMATION DRIVERS\n- These are the behaviours and attributes of the organization that are critical to successful change and ongoing performance.\n## Slide 7\n\n- 7\n- TGPS 2.0 | TGPS Model\n- Frequently Asked Questions (FAQs)\n## Slide 8\n\n- 02 TGPS Map\n## Slide 9\n\n- 9\n- TGPS 2.0 | TGPS Map\n- Overview\n- The map consists of four map zones (shown by separate colors) and 20 map regions (shown with labels)\n- The map represents 625 different driver profiles that were created from our database.\n- An organization’s placement on the map and those of its units, are driven by those survey questions included in the TGPS data model. [NOTE: Several standard questions are excluded; these are clearly indicated on the platform and on reports. See page 19 for detail]\n- An organization’s overall position indicates that change program’s current status – it could be High Performance, On Track, Unsustainable or Off Track.\n- The TGPS Map uses a color scheme to separately designate the map zones.\n- Each organization gets placed on the map via pattern-matching to our database of change journeys.\n## Slide 10\n\n- 10\n- TGPS 2.0 | TGPS Map\n- Frequently Asked Questions (FAQs)\n## Slide 11\n\n- 03 TGPS Database\n\n\n## Slide 37\n\n- Reporting Platform | Analyze / Overview\n- The right hand side of the analyze overview page includes four analysis widgets that are available by scrolling down.\n- Transformation GPS Results\n- The TGPS Results analysis shows the TGPS model arranged by drivers. The questions included under each driver contribute to the calculation of the driver unless marked with an asterisk. Drivers are expandable to show questions after being clicked.\n- Show: This option allows the user to filter the drivers shown\n- Sort Drivers: This changes the sorting of the Transformation Drivers according to either High to Low, Model Order or positive difference to comparison (if available).\n- View: This option lets the user choose the chart view they would prefer. By default Group Score is selected but Range Highlight and Difference are available.\n- Transformation GPS Questions\n- This analysis shows the top 10 questions (by default) from the Transformation Drivers. Clicking ‘Sort’ allows the user to see additionally, the bottom 10 questions, the largest positive differences and largest negative differences.\n- 37\n## Slide 38\n\n- 38\n- Reporting Platform | Analyze / Overview\n- The right hand side of the analyze overview page includes four analysis widgets that are available by scrolling down.\n- Human Capital Index (HCI)\n- The Human Capital Index analysis details the HCI calculation, how many individuals are in each map zone for the group selected.\x0b\n- NOTE: New analytics and visual features are under development and will be available in the near future.\n- Group Details\n- This table details all the groups that are currently being shown on the TGPS Map. The details include ‘Name’, Region and Zone on map, Responses and Response Rate for each group.\n\n\n## Slide 52\n\n- 52\n- Export ...
# Using model gpt-4o-dev for 6952.5 tokens (approx)
# LLM Response: with vars as (
# 	select 'Accenture' as company_name,
#     'Transformation GPS' as product_name,
#     'Cycle 1' as cycle_name
# )
# select
# 	count(d.id) as driver_count
# from product_versions pv
#     inner join programs_products pp on pp.product_version_id = pv.id
#     inner join ctre_program cp on cp.id = pp.program_id
#     inner join ctre_company cc on cc.id = cp.company_id
#     inner join ctre_cycle cc2 on cc2.program_id = cp.id
#
#     inner join drivers d on d.product_version_id = pv.id
#     inner join vars on true
# where 1=1
#     and cc."name" = company_name
#     and cp."name" = product_name
#     and cc2."name" = cycle_name
# ;
# Extracted SQL: with vars as (
# 	select 'Accenture' as company_name,
#     'Transformation GPS' as product_name,
#     'Cycle 1' as cycle_name
# )
# select
# 	count(d.id) as driver_count
# from product_versions pv
#     inner join programs_products pp on pp.product_version_id = pv.id
#     inner join ctre_program cp on cp.id = pp.program_id
#     inner join ctre_company cc on cc.id = cp.company_id
#     inner join ctre_cycle cc2 on cc2.program_id = cp.id
#
#     inner join drivers d on d.product_version_id = pv.id
#     inner join vars on true
# where 1=1
#     and cc."name" = company_name
#     and cp."name" = product_name
#     and cc2."name" = cycle_name
# ;
# If you want to run the SQL query, connect to a database first.

# %%
print(result_df)
# Out:
# None
