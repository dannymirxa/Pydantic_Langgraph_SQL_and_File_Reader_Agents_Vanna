# %%
import chromadb

# %%
chroma_client = chromadb.PersistentClient(path="./chroma_langchain_db")
# Out:
# Failed to send telemetry event ClientStartEvent: capture() takes 1 positional argument but 3 were given

# %%
chroma_client.list_collections()
# Out:
# ['ddl', 'documentation', 'sql']

# %%
collection = chroma_client.get_collection(name="sql")

# %%
result = collection.query(
    query_texts=[""],  # Replace with your actual query
    n_results=5
)
# Out:
# Failed to send telemetry event CollectionQueryEvent: capture() takes 1 positional argument but 3 were given

# %%
result['documents'][0]
# Out:
# ['{"question": "What is the question?", "sql": "--"}',
# ...

# %%
with open('tool_functions/product_version.sql', 'r') as f:
    sqlFile = f.read()

# %%
['--' + sql for sql in sqlFile.split('--')][1:]
# Out:
# ['-- Query 1: Retrieve the version of a product for a specific company and cycle.\nwith vars as (\n\tselect \'Accenture\' as company_name,\n    \'Transformation GPS\' as product_name,\n    \'Cycle 1\' as cycle_name\n)\nselect cc."name" company_name, cp."name" product_name, cc2."name" cycle_name, pv."version"\n    from ctre_program cp\n        inner join programs_products pp on pp.program_id = cp.id\n        inner join product_versions pv on pv.id = pp.product_version_id\n        inner join ctre_company cc on cc.id = cp.company_id\n        inner join ctre_cycle cc2 on cc2.program_id = cp.id\n        inner join vars on true\nwhere 1=1\n    and cc."name" = company_name\n    and cp."name" = product_name\n    and cc2."name" = cycle_name\n;\n\n',
# ...
